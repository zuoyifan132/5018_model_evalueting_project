# %%
from google.colab import drive

drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install torch
# !pip install transformers
# !pip install numpy
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 72.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 122.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Import 

import os
import csv
import json
import math
import torch
import argparse
import difflib
import logging
import numpy as np
import pandas as pd

from transformers import BertTokenizer, BertForMaskedLM
from transformers import AlbertTokenizer, AlbertForMaskedLM
from transformers import RobertaTokenizer, RobertaForMaskedLM
from collections import defaultdict
from tqdm import tqdm

# %%
def read_data(input_file):
    """
    Load data into pandas DataFrame format.
    """
    
    df_data = pd.DataFrame(columns=['sent1', 'sent2', 'direction', 'bias_type'])

    with open(input_file) as f:
        reader = csv.DictReader(f)
        for row in reader:
            direction, gold_bias = '_', '_'
            direction = row['stereo_antistereo']
            bias_type = row['bias_type']

            # sent1 should be stereo, sent2 should be less stereo
            sent1, sent2 = '', ''
            if direction == 'stereo':
                sent1 = row['sent_more']
                sent2 = row['sent_less']
            else:
                sent1 = row['sent_less']
                sent2 = row['sent_more']

            df_item = {'sent1': sent1,
                       'sent2': sent2,
                       'direction': direction,
                       'bias_type': bias_type}
            df_data = df_data.append(df_item, ignore_index=True)

    return df_data

# %%
def get_log_prob_unigram(masked_token_ids, token_ids, mask_idx, lm):
    """
    Given a sequence of token ids, with one masked token, return the log probability of the masked token.
    """
    
    model = lm["model"]
    tokenizer = lm["tokenizer"]
    log_softmax = lm["log_softmax"]
    mask_token = lm["mask_token"]
    uncased = lm["uncased"]

    # get model hidden states
    output = model(masked_token_ids)
    hidden_states = output[0].squeeze(0)
    mask_id = tokenizer.convert_tokens_to_ids(mask_token)

    # we only need log_prob for the MASK tokens
    assert masked_token_ids[0][mask_idx] == mask_id

    hs = hidden_states[mask_idx]
    target_id = token_ids[0][mask_idx]
    log_probs = log_softmax(hs)[target_id]

    return log_probs

# %%
def get_span(seq1, seq2):
    """
    This function extract spans that are shared between two sequences.
    """

    seq1 = [str(x) for x in seq1.tolist()]
    seq2 = [str(x) for x in seq2.tolist()]

    matcher = difflib.SequenceMatcher(None, seq1, seq2)
    template1, template2 = [], []
    for op in matcher.get_opcodes():
        # each op is a list of tuple: 
        # (operation, pro_idx_start, pro_idx_end, anti_idx_start, anti_idx_end)
        # possible operation: replace, insert, equal
        # https://docs.python.org/3/library/difflib.html
        if op[0] == 'equal':
            template1 += [x for x in range(op[1], op[2], 1)]
            template2 += [x for x in range(op[3], op[4], 1)]

    return template1, template2

# %%
def mask_unigram(data, lm, n=1):
    """
    Score each sentence by masking one word at a time.
    The score for a sentence is the sum of log probability of each word in
    the sentence.
    n = n-gram of token that is masked, if n > 1, we mask tokens with overlapping
    n-grams.
    """
    model = lm["model"]
    tokenizer = lm["tokenizer"]
    log_softmax = lm["log_softmax"]
    mask_token = lm["mask_token"]
    uncased = lm["uncased"]

    if torch.cuda.is_available():
        torch.set_default_tensor_type('torch.cuda.FloatTensor')

    sent1, sent2 = data["sent1"], data["sent2"]

    if uncased:
        sent1 = sent1.lower()
        sent2 = sent2.lower()

    # tokenize
    sent1_token_ids = tokenizer.encode(sent1, return_tensors='pt')
    sent2_token_ids = tokenizer.encode(sent2, return_tensors='pt')

    # get spans of non-changing tokens
    template1, template2 = get_span(sent1_token_ids[0], sent2_token_ids[0])

    assert len(template1) == len(template2)

    N = len(template1)  # num. of tokens that can be masked
    mask_id = tokenizer.convert_tokens_to_ids(mask_token)
    
    sent1_log_probs = 0.
    sent2_log_probs = 0.
    total_masked_tokens = 0

    # skipping CLS and SEP tokens, they'll never be masked
    for i in range(1, N-1):
        sent1_masked_token_ids = sent1_token_ids.clone().detach()
        sent2_masked_token_ids = sent2_token_ids.clone().detach()

        sent1_masked_token_ids[0][template1[i]] = mask_id
        sent2_masked_token_ids[0][template2[i]] = mask_id
        total_masked_tokens += 1

        score1 = get_log_prob_unigram(sent1_masked_token_ids, sent1_token_ids, template1[i], lm)
        score2 = get_log_prob_unigram(sent2_masked_token_ids, sent2_token_ids, template2[i], lm)

        sent1_log_probs += score1.item()
        sent2_log_probs += score2.item()

    score = {}
    # average over iterations
    score["sent1_score"] = sent1_log_probs
    score["sent2_score"] = sent2_log_probs

    return score

# %%
def evaluate(input_file, lm_model, output_file):
    """
    Evaluate a masked language model using CrowS-Pairs dataset.
    """

    print("Evaluating:")
    print("Input:", input_file)
    print("Model:", lm_model)
    print("=" * 100)

    logging.basicConfig(level=logging.INFO)

    # load data into panda DataFrame
    df_data = read_data(input_file)

    # supported masked language models
    if lm_model == "bert":
        tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
        model = BertForMaskedLM.from_pretrained('bert-base-uncased')
        uncased = True
    elif lm_model == "roberta":
        tokenizer = RobertaTokenizer.from_pretrained('roberta-large')
        model = RobertaForMaskedLM.from_pretrained('roberta-large')
        uncased = False
    elif lm_model == "albert":
        tokenizer = AlbertTokenizer.from_pretrained('albert-xxlarge-v2')
        model = AlbertForMaskedLM.from_pretrained('albert-xxlarge-v2')
        uncased = True

    model.eval()
    if torch.cuda.is_available():
        model.to('cuda')

    mask_token = tokenizer.mask_token
    log_softmax = torch.nn.LogSoftmax(dim=0)
    vocab = tokenizer.get_vocab()
    with open(lm_model + ".vocab", "w") as f:
        f.write(json.dumps(vocab))

    lm = {"model": model,
          "tokenizer": tokenizer,
          "mask_token": mask_token,
          "log_softmax": log_softmax,
          "uncased": uncased
    }

    # score each sentence. 
    # each row in the dataframe has the sentid and score for pro and anti stereo.
    df_score = pd.DataFrame(columns=['sent_more', 'sent_less', 
                                     'sent_more_score', 'sent_less_score',
                                     'score', 'stereo_antistereo', 'bias_type'])

    # total_stereo: total number of labeled as stereo in data
    # total_antistereo: total number of labeled as anti-stereo in data
    # stereo_score: total number of true stereo in data
    # antistereo_score: total number of true anti-stereo in data
    total_stereo, total_antistereo = 0, 0
    stereo_score, antistereo_score = 0, 0

    N = 0
    neutral = 0
    total = len(df_data.index)
    with tqdm(total=total) as pbar:
        for index, data in df_data.iterrows():
            direction = data['direction']
            bias = data['bias_type']
            score = mask_unigram(data, lm)

            for stype in score.keys():
                score[stype] = round(score[stype], 3)

            N += 1
            # the number of true paired two sentences that matched the label
            pair_score = 0
            pbar.update(1)

            # no bias 
            if score['sent1_score'] == score['sent2_score']:
                neutral += 1
            # has bias
            else:
                if direction == 'stereo':
                    total_stereo += 1
                    if score['sent1_score'] > score['sent2_score']:
                        stereo_score += 1
                        pair_score = 1
                elif direction == 'antistereo':
                    total_antistereo += 1
                    if score['sent2_score'] > score['sent1_score']:
                        antistereo_score += 1
                        pair_score = 1

            sent_more, sent_less = '', ''
            if direction == 'stereo':
                sent_more = data['sent1']
                sent_less = data['sent2']
                sent_more_score = score['sent1_score']
                sent_less_score = score['sent2_score']
            else:
                sent_more = data['sent2']
                sent_less = data['sent1']
                sent_more_score = score['sent2_score']
                sent_less_score = score['sent1_score']

            df_score = df_score.append({'sent_more': sent_more,
                                        'sent_less': sent_less,
                                        'sent_more_score': sent_more_score,
                                        'sent_less_score': sent_less_score,
                                        'score': pair_score,
                                        'stereo_antistereo': direction,
                                        'bias_type': bias
                                      }, ignore_index=True)


    df_score.to_csv(output_file)
    print('=' * 100)
    print('Total examples:', N)
    print('Metric score:', round((stereo_score + antistereo_score) / N * 100, 2))                   # true labeled pairs rate
    print('Stereotype score:', round(stereo_score  / total_stereo * 100, 2))                        # true stereo labeled pairs out of all stereo pairs
    if antistereo_score != 0:
        print('Anti-stereotype score:', round(antistereo_score  / total_antistereo * 100, 2))       # true anti-stereo labeled pairs out of all anti-stereo pairs
    print("Num. neutral:", neutral, round(neutral / N * 100, 2))
    print('=' * 100)
    print()

# %%
input_file = "gdrive/MyDrive/5002_Final_Project_Data/gender_bias_data.csv"
model_name = "bert"
output_file = "gdrive/MyDrive/5002_Final_Project_Data/output_bert.csv"

evaluate(input_file, model_name, output_file)
# Out:
# Evaluating:
# Input: gdrive/MyDrive/5002_Final_Project_Data/gender_bias_data.csv
# Model: bert
# ====================================================================================================
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# ...
#   df_score = df_score.append({'sent_more': sent_more,
#  79%|███████▊  | 206/262 [01:40<00:21,  2.62it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  79%|███████▉  | 207/262 [01:40<00:18,  3.02it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  79%|███████▉  | 208/262 [01:41<00:19,  2.81it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  80%|███████▉  | 209/262 [01:41<00:20,  2.59it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  80%|████████  | 210/262 [01:42<00:24,  2.11it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  81%|████████  | 211/262 [01:42<00:22,  2.29it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  81%|████████  | 212/262 [01:43<00:21,  2.29it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  81%|████████▏ | 213/262 [01:43<00:21,  2.32it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  82%|████████▏ | 214/262 [01:44<00:22,  2.10it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  82%|████████▏ | 215/262 [01:45<00:27,  1.70it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  82%|████████▏ | 216/262 [01:45<00:25,  1.81it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  83%|████████▎ | 217/262 [01:46<00:24,  1.87it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  83%|████████▎ | 218/262 [01:46<00:24,  1.78it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  84%|████████▎ | 219/262 [01:46<00:20,  2.06it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  84%|████████▍ | 220/262 [01:47<00:19,  2.15it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  84%|████████▍ | 221/262 [01:47<00:20,  2.00it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  85%|████████▍ | 222/262 [01:48<00:17,  2.32it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  85%|████████▌ | 223/262 [01:48<00:14,  2.61it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  85%|████████▌ | 224/262 [01:48<00:14,  2.67it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  86%|████████▌ | 225/262 [01:49<00:14,  2.63it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  86%|████████▋ | 226/262 [01:49<00:12,  2.96it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  87%|████████▋ | 227/262 [01:49<00:10,  3.43it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  87%|████████▋ | 228/262 [01:49<00:10,  3.33it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  87%|████████▋ | 229/262 [01:50<00:10,  3.05it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  88%|████████▊ | 230/262 [01:50<00:12,  2.56it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  88%|████████▊ | 231/262 [01:51<00:11,  2.81it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  89%|████████▊ | 232/262 [01:51<00:08,  3.54it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  89%|████████▉ | 233/262 [01:51<00:07,  3.67it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  89%|████████▉ | 234/262 [01:51<00:08,  3.49it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  90%|████████▉ | 235/262 [01:52<00:08,  3.28it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  90%|█████████ | 236/262 [01:52<00:09,  2.64it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  90%|█████████ | 237/262 [01:53<00:09,  2.68it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  91%|█████████ | 238/262 [01:53<00:10,  2.23it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  91%|█████████ | 239/262 [01:54<00:09,  2.50it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  92%|█████████▏| 240/262 [01:54<00:08,  2.48it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  92%|█████████▏| 241/262 [01:55<00:10,  2.09it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  92%|█████████▏| 242/262 [01:55<00:09,  2.20it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  93%|█████████▎| 243/262 [01:55<00:07,  2.58it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  93%|█████████▎| 244/262 [01:56<00:07,  2.47it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  94%|█████████▎| 245/262 [01:56<00:06,  2.60it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  94%|█████████▍| 246/262 [01:57<00:06,  2.32it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  94%|█████████▍| 247/262 [01:57<00:05,  2.59it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  95%|█████████▍| 248/262 [01:57<00:06,  2.25it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  95%|█████████▌| 249/262 [01:58<00:06,  1.94it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  95%|█████████▌| 250/262 [01:58<00:05,  2.36it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  96%|█████████▌| 251/262 [01:59<00:04,  2.62it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  96%|█████████▌| 252/262 [01:59<00:03,  2.89it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  97%|█████████▋| 253/262 [02:00<00:04,  2.21it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  97%|█████████▋| 254/262 [02:00<00:03,  2.11it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  97%|█████████▋| 255/262 [02:01<00:04,  1.70it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  98%|█████████▊| 256/262 [02:01<00:03,  1.93it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  98%|█████████▊| 257/262 [02:02<00:02,  2.21it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  98%|█████████▊| 258/262 [02:02<00:02,  1.94it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  99%|█████████▉| 259/262 [02:03<00:01,  2.18it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  99%|█████████▉| 260/262 [02:03<00:00,  2.65it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
# 100%|█████████▉| 261/262 [02:03<00:00,  3.20it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
# 100%|██████████| 262/262 [02:03<00:00,  2.83it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
# 100%|██████████| 262/262 [02:03<00:00,  2.11it/s]
# ====================================================================================================
# Total examples: 262
# Metric score: 58.02
# Stereotype score: 55.35
# Anti-stereotype score: 62.14
# Num. neutral: 0 0.0
# ====================================================================================================

# %%
input_file = "gdrive/MyDrive/5002_Final_Project_Data/gender_bias_data.csv"
model_name = "roberta"
output_file = "gdrive/MyDrive/5002_Final_Project_Data/output_roberta.csv"

evaluate(input_file, model_name, output_file)
# Out:
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# Evaluating:
# Input: gdrive/MyDrive/5002_Final_Project_Data/gender_bias_data.csv
# Model: roberta
# ====================================================================================================
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# ...
#   df_score = df_score.append({'sent_more': sent_more,
#  79%|███████▊  | 206/262 [02:39<01:00,  1.08s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  79%|███████▉  | 207/262 [02:40<00:46,  1.18it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  79%|███████▉  | 208/262 [02:40<00:41,  1.30it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  80%|███████▉  | 209/262 [02:41<00:37,  1.43it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  80%|████████  | 210/262 [02:42<00:40,  1.27it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  81%|████████  | 211/262 [02:42<00:36,  1.42it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  81%|████████  | 212/262 [02:43<00:34,  1.46it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  81%|████████▏ | 213/262 [02:44<00:32,  1.52it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  82%|████████▏ | 214/262 [02:45<00:49,  1.02s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  82%|████████▏ | 215/262 [02:48<01:14,  1.58s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  82%|████████▏ | 216/262 [02:50<01:08,  1.49s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  83%|████████▎ | 217/262 [02:51<01:00,  1.34s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  83%|████████▎ | 218/262 [02:53<01:08,  1.55s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  84%|████████▎ | 219/262 [02:53<00:54,  1.28s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  84%|████████▍ | 220/262 [02:54<00:51,  1.23s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  84%|████████▍ | 221/262 [02:56<00:54,  1.32s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  85%|████████▍ | 222/262 [02:57<00:46,  1.17s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  85%|████████▌ | 223/262 [02:57<00:40,  1.04s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  85%|████████▌ | 224/262 [02:59<00:39,  1.05s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  86%|████████▌ | 225/262 [03:00<00:45,  1.23s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  86%|████████▋ | 226/262 [03:01<00:38,  1.06s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  87%|████████▋ | 227/262 [03:01<00:31,  1.12it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  87%|████████▋ | 228/262 [03:02<00:29,  1.14it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  87%|████████▋ | 229/262 [03:04<00:42,  1.29s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  88%|████████▊ | 230/262 [03:06<00:43,  1.35s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  88%|████████▊ | 231/262 [03:07<00:36,  1.19s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  89%|████████▊ | 232/262 [03:07<00:28,  1.06it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  89%|████████▉ | 233/262 [03:08<00:25,  1.14it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  89%|████████▉ | 234/262 [03:09<00:23,  1.18it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  90%|████████▉ | 235/262 [03:10<00:23,  1.13it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  90%|█████████ | 236/262 [03:11<00:30,  1.19s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  90%|█████████ | 237/262 [03:13<00:35,  1.42s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  91%|█████████ | 238/262 [03:18<00:55,  2.33s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  91%|█████████ | 239/262 [03:20<00:51,  2.26s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  92%|█████████▏| 240/262 [03:22<00:48,  2.19s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  92%|█████████▏| 241/262 [03:25<00:50,  2.38s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  92%|█████████▏| 242/262 [03:25<00:37,  1.86s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  93%|█████████▎| 243/262 [03:26<00:27,  1.43s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  93%|█████████▎| 244/262 [03:27<00:21,  1.21s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  94%|█████████▎| 245/262 [03:27<00:16,  1.01it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  94%|█████████▍| 246/262 [03:28<00:14,  1.07it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  94%|█████████▍| 247/262 [03:28<00:11,  1.28it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  95%|█████████▍| 248/262 [03:29<00:11,  1.25it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  95%|█████████▌| 249/262 [03:30<00:10,  1.19it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  95%|█████████▌| 250/262 [03:30<00:08,  1.47it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  96%|█████████▌| 251/262 [03:31<00:07,  1.53it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  96%|█████████▌| 252/262 [03:32<00:06,  1.58it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  97%|█████████▋| 253/262 [03:33<00:06,  1.35it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  97%|█████████▋| 254/262 [03:34<00:06,  1.25it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  97%|█████████▋| 255/262 [03:36<00:09,  1.41s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  98%|█████████▊| 256/262 [03:37<00:07,  1.31s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  98%|█████████▊| 257/262 [03:38<00:05,  1.19s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  98%|█████████▊| 258/262 [03:40<00:05,  1.41s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  99%|█████████▉| 259/262 [03:41<00:03,  1.19s/it]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
#  99%|█████████▉| 260/262 [03:41<00:01,  1.04it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
# 100%|█████████▉| 261/262 [03:42<00:00,  1.30it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
# 100%|██████████| 262/262 [03:43<00:00,  1.23it/s]<ipython-input-8-0f343dc1eaec>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_score = df_score.append({'sent_more': sent_more,
# 100%|██████████| 262/262 [03:43<00:00,  1.17it/s]
# ====================================================================================================
# Total examples: 262
# Metric score: 58.4
# Stereotype score: 59.12
# Anti-stereotype score: 57.28
# Num. neutral: 0 0.0
# ====================================================================================================

# %%
input_file = "gdrive/MyDrive/5002_Final_Project_Data/gender_bias_data.csv"
model_name = "albert"
output_file = "gdrive/MyDrive/5002_Final_Project_Data/output_albert.csv"

evaluate(input_file, model_name, output_file)
# Out:
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# Evaluating:
# Input: gdrive/MyDrive/5002_Final_Project_Data/gender_bias_data.csv
# Model: albert
# ====================================================================================================
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# <ipython-input-4-89c0698653f7>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_data = df_data.append(df_item, ignore_index=True)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-6e068411f90e> in <cell line: 5>()
#       3 output_file = "gdrive/MyDrive/5002_Final_Project_Data/output_albert.csv"
#       4
# ----> 5 evaluate(input_file, model_name, output_file)
#
# <ipython-input-8-0f343dc1eaec> in evaluate(input_file, lm_model, output_file)
#      24         uncased = False
#      25     elif lm_model == "albert":
# ---> 26         tokenizer = AlbertTokenizer.from_pretrained('albert-xxlarge-v2')
#      27         model = AlbertForMaskedLM.from_pretrained('albert-xxlarge-v2')
#      28         uncased = True
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in __getattribute__(cls, key)
#    1110         if key.startswith("_") and key != "_from_config":
#    1111             return super().__getattribute__(key)
# -> 1112         requires_backends(cls, cls._backends)
#    1113
#    1114
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in requires_backends(obj, backends)
#    1098     failed = [msg.format(name) for available, msg in checks if not available()]
#    1099     if failed:
# -> 1100         raise ImportError("".join(failed))
#    1101
#    1102
#
# ImportError:
# AlbertTokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment. Please note that you may need to restart your runtime after installation.
#
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
